# %% [markdown]
# - add more Keywords 'q' param
# - News Source
# - Clean data
# - Remove rank
# - no need for relevancy param

# %%
# Import packages
# Default packages
import time
import csv
import os
import json


# Preinstalled packages
import requests
import pandas



# Define desired work folder, where you want to save your .csv files
# Windows Example
os.chdir('C:\\Users\\sheru\\Documents\\Python Code\\Data Mining Project\\news_data')

# URL of our News API
base_url = 'https://api.newscatcherapi.com/v2/search'

# Your API key
X_API_KEY = 'zLGQJIfbcBPWCXBoupbkRkBfb9HW_bRBRdKZ_Oeuenw'

# %%
# Put your API key to headers in order to be authorized to perform a call
headers = {'x-api-key': 'zLGQJIfbcBPWCXBoupbkRkBfb9HW_bRBRdKZ_Oeuenw'}

# Define your desired parameters
params = {
    'q': 'Israel AND Palestine',
    'published_date_precision':'date',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'page': 1,
    'to':'2023/10/01',
    'from':'2020/10/01'
    }

# Make a simple call with both headers and params
response = requests.get(base_url, headers=headers, params=params)

# Encode received results
results = json.loads(response.text.encode())
if response.status_code == 200:
    print('Done')
else:
    print(results)
    print('ERROR: API call failed.')
# Out:
# Done

# %%
# Variable to store all found news articles
all_news_articles = []

# Ensure that we start from page 1
params['page'] = 1

# Infinite loop which ends when all articles are extracted
while True:

    # Wait for 1 second between each call
    time.sleep(1)

    # GET Call from previous section enriched with some logs
    response = requests.get(base_url, headers=headers, params=params)
    results = json.loads(response.text.encode())
    if response.status_code == 200:
        print(f'Done for page number => {params["page"]}')


        # Adding your parameters to each result to be able to explore afterwards
        for i in results['articles']:
            i['used_params'] = str(params)


        # Storing all found articles
        all_news_articles.extend(results['articles'])

        # Ensuring to cover all pages by incrementing "page" value at each iteration
        params['page'] += 1
        if params['page'] > results['total_pages']:
            print("All articles have been extracted")
            break
        else:
            print(f'Proceed extracting page number => {params["page"]}')
    else:
        print(results)
        print(f'ERROR: API call failed for page number => {params["page"]}')
        break

print(f'Number of extracted articles => {str(len(all_news_articles))}')
# Out:
# Done for page number => 1
# Proceed extracting page number => 2
# Done for page number => 2
# Proceed extracting page number => 3
# Done for page number => 3
# Proceed extracting page number => 4
# Done for page number => 4
# Proceed extracting page number => 5
# Done for page number => 5
# Proceed extracting page number => 6
# Done for page number => 6
# Proceed extracting page number => 7
# Done for page number => 7
# Proceed extracting page number => 8
# Done for page number => 8
# Proceed extracting page number => 9
# Done for page number => 9
# Proceed extracting page number => 10
# Done for page number => 10
# Proceed extracting page number => 11
# Done for page number => 11
# All articles have been extracted
# Number of extracted articles => 1099

# %%
# Import data into pandas
pandas_table = pd.DataFrame(all_news_articles)
pandas_table
# Out:
#                                                   title  \
# 0     Water, Vol. 13, Pages 620: Implementation Cons...
# 1     Palestine urges UNSC to stop Israel from obstr...
# 2     America's double standards aggravate humanitar...
# 3     Ghosts Of The Past: For Israel, War On UNESCO ...
# 4     Palestine's Delegation Presents Unyielding Cas...
# ...                                                 ...
# 1094       Transcript: All In with Chris Hayes, 5/19/21
# 1095  Prevalence and Concentration of Mycotoxins in ...
# 1096  Vaccine Hesitancy of COVID-19 among Parents fo...
# 1097  Norway's largest pension fund stops investing ...
# 1098  Meet the Cast of PARADISE SQUARE; Beginning Pr...
#
#                       author       published_date published_date_precision  \
# 0                 Liping Dai  2021-02-27 00:00:00                     date
# 1                      F_487  2021-04-23 00:00:00                     date
# 2                      F_126  2021-07-08 00:00:00                     date
# 3                     MENAFN  2023-09-26 00:00:00                     date
# 4                     MENAFN  2023-07-24 00:00:00                     date
# ...                      ...                  ...                      ...
# 1094                    None  2021-05-20 00:00:00                     date
# 1095  Ghader Jalilzadeh-Amin  2023-03-10 00:00:00                     date
# 1096   Muhammad Shahid Iqbal  2023-10-01 00:00:00                     date
# 1097                     Jul  2021-07-05 00:00:00                     date
# 1098             Stephi Wild  2022-03-15 00:00:00                     date
#
#                                                    link            clean_url  \
# 0               https://www.mdpi.com/2073-4441/13/5/620             mdpi.com
# 1     http://en.people.cn/n3/2021/0423/c90000-984269...            people.cn
# 2     http://en.people.cn/n3/2021/0708/c98649-986987...            people.cn
# 3     https://menafn.com/1107148257/Ghosts-Of-The-Pa...           menafn.com
# 4     https://menafn.com/1106663529/Palestines-Deleg...           menafn.com
# ...                                                 ...                  ...
# 1094  https://www.msnbc.com/transcripts/transcript-a...            msnbc.com
# 1095            https://www.mdpi.com/2072-6651/15/3/214             mdpi.com
# 1096          https://www.mdpi.com/2076-393X/11/10/1556             mdpi.com
# 1097  https://www.thenationalnews.com/mena/2021/07/0...  thenationalnews.com
# 1098  https://www.broadwayworld.com/article/Meet-the...    broadwayworld.com
#
#                                                 excerpt  \
# 0     This study uses a diagnostic and multidiscipli...
# 1     (Xinhua) 11:13, April 23, 2021 RAMALLAH, April...
# 2     Home>>People's Daily Online Exclusives By Su J...
# 3     Jericho does not belong to the Palestinians al...
# 4     Bethlehem/PNN /State of Palestine's delegation...
# ...                                                 ...
# 1094  Guests: Jim McGovern, Danya Perry, David Faren...
# 1095  This study seeks a comprehensive meta-analysis...
# 1096  The current systematic review presents COVID-1...
# 1097  KLP says the businesses are involved in illega...
# 1098  Paradise Square begins previews on Broadway to...
#
#                                                 summary  \
# 0     This is an early access version, the complete ...
# 1     (Xinhua) 11:13, April 23, 2021 RAMALLAH, April...
# 2     Home>>People's Daily Online Exclusives By Su J...
# 3     (MENAFN- Jordan Times) Jericho does not belong...
# 4     State of Palestine's delegation, headed by Dr....
# ...                                                 ...
# 1094  Tonight, the House voted 252 to 175 with just ...
# 1095  Department of Clinical Pathology and Internal ...
# 1096  Open Access\nSystematic Review\n \n \n\n\n\n\n...
# 1097  wo25-israel-bedouin-BL The Jewish settlement o...
# 1098  Paradise Square begins previews on Broadway to...
#
#                                     rights  rank    topic country language  \
# 0     Creative Commons Attribution (CC-BY)   449     news      CH       en
# 1                                people.cn  2235     news      CN       en
# 2                                people.cn  2235     news      CN       en
# 3                               menafn.com  6165     news      US       en
# 4                               menafn.com  6165     news      US       en
# ...                                    ...   ...      ...     ...      ...
# 1094                             msnbc.com   965     news      US       en
# 1095  Creative Commons Attribution (CC-BY)   449  science      CH       en
# 1096  Creative Commons Attribution (CC-BY)   449  science      CH       en
# 1097                   thenationalnews.com  2585     news      AE       en
# 1098                     broadwayworld.com  2460     news      US       en
#
#                                                 authors  \
# 0                                          [Liping Dai]
# 1                                               [F_487]
# 2                                               [F_126]
# 3                                                MENAFN
# 4                                                MENAFN
# ...                                                 ...
# 1094                                                 []
# 1095  Ahmadnejad-Asl-Gavgani,Aziz A.,Aziz A. Fallah,...
# 1096  Iqbal,Khan,Muhammad Shahid,Muhammad Shahid Iqb...
# 1097                                              [Jul]
# 1098                                        Stephi Wild
#
#                                                   media  is_opinion  \
# 0     https://www.mdpi.com/img/journals/water-logo-s...       False
# 1     http://en.people.cn/NMediaFile/2021/0416/FOREI...       False
# 2     http://en.people.cn/NMediaFile/2021/0708/FOREI...       False
# 3              https://menafn.com/includes/img/logo.jpg       False
# 4     https://menafn.com/updates/pr/2023-07/24/PNN_4...       False
# ...                                                 ...         ...
# 1094  https://media-cldnry.s-nbcnews.com/image/uploa...       False
# 1095  https://pub.mdpi-res.com/toxins/toxins-15-0021...       False
# 1096  https://pub.mdpi-res.com/vaccines/vaccines-11-...       False
# 1097  https://www.thenationalnews.com/resizer/wqobo7...       False
# 1098  https://cloudimages.broadwayworld.com/columnpi...       False
#
#       twitter_account     _score                               _id  \
# 0                None  23.232014  e78e7ae985549a735579a06b71c1452a
# 1                None  22.741539  d4eb60c19c3cb9a5aca303324ed102a5
# 2                None  22.684639  e14ba65b00c5c876157aca7c1c984236
# 3             @menafn  22.282198  9d2d84073bac54c4e0a2916691899887
# 4             @menafn  22.147934  208477dd2ed369d94c68ec54bbd5afe7
# ...               ...        ...                               ...
# 1094           @MSNBC   4.538241  d9be2295d4a1654c752215eb3dd538ab
# 1095  @MDPIOpenAccess   4.535970  a7fe20f041d4bbabad0a6dcea689dae9
# 1096  @MDPIOpenAccess   3.962043  148ad925630694f1470d0568d7908635
# 1097     @TheNational   3.818881  3d77ad97108e6503adbdc10ea3eed6e1
# 1098   @broadwayworld   3.300784  9046280a96f112cb30eaa9e81411ec68
#
#                                             used_params
# 0     {'q': 'Israel AND Palestine', 'published_date_...
# 1     {'q': 'Israel AND Palestine', 'published_date_...
# 2     {'q': 'Israel AND Palestine', 'published_date_...
# 3     {'q': 'Israel AND Palestine', 'published_date_...
# 4     {'q': 'Israel AND Palestine', 'published_date_...
# ...                                                 ...
# 1094  {'q': 'Israel AND Palestine', 'published_date_...
# 1095  {'q': 'Israel AND Palestine', 'published_date_...
# 1096  {'q': 'Israel AND Palestine', 'published_date_...
# 1097  {'q': 'Israel AND Palestine', 'published_date_...
# 1098  {'q': 'Israel AND Palestine', 'published_date_...
#
# [1099 rows x 20 columns]

# %%
csv_data = pandas_table.to_csv('news.csv', index = True) 
print('\nCSV String:\n', csv_data)
# Out:
# CSV String:
#  None
